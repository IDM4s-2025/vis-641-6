# %%
import pandas as pd
import requests

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/gdp-per-capita-worldbank.csv?v=1&csvType=full&useColumnShortNames=true", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Fetch the metadata
metadata = requests.get("https://ourworldindata.org/grapher/gdp-per-capita-worldbank.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

df
# Out:
#            Entity Code  Year  ny_gdp_pcap_pp_kd
# 0     Afghanistan  AFG  2000          1617.8264
# 1     Afghanistan  AFG  2001          1454.1108
# 2     Afghanistan  AFG  2002          1774.3087
# 3     Afghanistan  AFG  2003          1815.9282
# 4     Afghanistan  AFG  2004          1776.9182
# ...           ...  ...   ...                ...
# 7058     Zimbabwe  ZWE  2019          3294.8062
# 7059     Zimbabwe  ZWE  2020          2987.2698
# 7060     Zimbabwe  ZWE  2021          3184.7854
# 7061     Zimbabwe  ZWE  2022          3323.1218
# 7062     Zimbabwe  ZWE  2023          3442.2512
#
# [7063 rows x 4 columns]

# %%
af = pd.read_csv("OECD.csv")

af
# Out:
#     STRUCTURE      STRUCTURE_ID     STRUCTURE_NAME ACTION LOCATION  \
# 0    DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      AUT
# 1    DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      BEL
# 2    DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CZE
# 3    DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      DNK
# 4    DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      FIN
# ..        ...               ...                ...    ...      ...
# 111  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      SVN
# 112  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I     OECD
# 113  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      COL
# 114  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      LTU
# 115  DATAFLOW  OECD:DF_BLI(1.0)  Better Life Index      I      CRI
#
#           Country INDICATOR                           Indicator MEASURE  \
# 0         Austria   HO_BASE  Dwellings without basic facilities       L
# 1         Belgium   HO_BASE  Dwellings without basic facilities       L
# 2         Czechia   HO_BASE  Dwellings without basic facilities       L
# 3         Denmark   HO_BASE  Dwellings without basic facilities       L
# 4         Finland   HO_BASE  Dwellings without basic facilities       L
# ..            ...       ...                                 ...     ...
# 111      Slovenia   HO_NUMR                    Rooms per person       L
# 112  OECD - Total   HO_NUMR                    Rooms per person       L
# 113      Colombia   HO_NUMR                    Rooms per person       L
# 114     Lithuania   HO_NUMR                    Rooms per person       L
# 115    Costa Rica   HO_NUMR                    Rooms per person       L
#
#     Measure  ... OBS_VALUE  Observation Value  OBS_STATUS  Observation Status  \
# 0     Value  ...       0.8                NaN           A                 NaN
# 1     Value  ...       0.7                NaN           A                 NaN
# 2     Value  ...       0.5                NaN           A                 NaN
# 3     Value  ...       0.5                NaN           A                 NaN
# 4     Value  ...       0.4                NaN           A                 NaN
# ..      ...  ...       ...                ...         ...                 ...
# 111   Value  ...       1.6                NaN           A                 NaN
# 112   Value  ...       1.7                NaN           A                 NaN
# 113   Value  ...       1.0                NaN           A                 NaN
# 114   Value  ...       1.5                NaN           A                 NaN
# 115   Value  ...       1.2                NaN           A                 NaN
#
#     UNIT_MEASURE  Unit of Measures UNIT_MULT Multiplier  BASE_PER  \
# 0             PC        Percentage         0      Units       NaN
# 1             PC        Percentage         0      Units       NaN
# 2             PC        Percentage         0      Units       NaN
# 3             PC        Percentage         0      Units       NaN
# 4             PC        Percentage         0      Units       NaN
# ..           ...               ...       ...        ...       ...
# 111        RATIO             Ratio         0      Units       NaN
# 112        RATIO             Ratio         0      Units       NaN
# 113        RATIO             Ratio         0      Units       NaN
# 114        RATIO             Ratio         0      Units       NaN
# 115        RATIO             Ratio         0      Units       NaN
#
#     Base reference period
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ..                    ...
# 111                   NaN
# 112                   NaN
# 113                   NaN
# 114                   NaN
# 115                   NaN
#
# [116 rows x 22 columns]
